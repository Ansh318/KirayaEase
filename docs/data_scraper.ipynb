# %% [markdown]
# 🧾 KYC + Identity Verification
# To know who they are:
#
# DigiLocker APIs – Aadhaar, PAN, DL, Voter ID
#
# Selfie OCR – Compare selfie with PAN/Aadhaar image using Azure/Google Vision
#
# Mobile/email verification – Already doing this with OTP
#
# 🧮 Income & Risk Assessment
# To know if they can afford rent:
#
# Bank Statement Parsing (PDF or via AA) → Use:
#
# Karza
#
# Perfios
#
# Or Account Aggregator (AA) APIs: like Setu, FinBox, OneMoney
#
# Salary Slips / Form 16 Uploads (fallback)
#
# Employer Verification (via LinkedIn or domain match?)
#
# 🧑‍💼 Behavioral Data for Creditworthiness
# To underwrite intelligently:
#
# Rent Payment History (from KirayaEase platform!)
#
# UPI transaction analysis (esp. rent tagged)
#
# Spending habits (via AA or UPI insights)
#
# Geo-data – city, area, rent benchmarks
#
# 📊 Rental Intelligence & Property Data
# To provide market insights:
#
# MagicBricks + 99acres + NoBroker scraping
#
# Government data – Circle rates, municipal records
#
# Google Maps API – School, hospital, metro proximity
#
# In-house platform data – Average rents, vacancy heatmaps
#
# 💳 Post-onboarding for Monitoring & Offers
# To offer financial intelligence:
#
# Spending anomalies → Early warning for rent stress
#
# Salary drops or delays (via AA)
#
# Recurring subscription payments
#
# 🧠 Bonus AI Features You Can Train Later
# Risk-scoring model from behavioral + financial data
#
# Rent recommendation engine based on profile + geography
#
# Dynamic interest/milestone structuring based on liquidity

# %%
import PyPDF2

def pdf_to_text(path: str) -> str:
    """Reads a PDF file and returns all text as a single string."""
    text = []
    with open(path, "rb") as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text.append(page_text)
    return "\n".join(text)

# Example usage:
if __name__ == "__main__":
    content = pdf_to_text("/Users/anshagarwal/Desktop/KirayaEase/data/Lease_Agreement_Sample.pdf")
    print(content)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv311 (Python 3.11.13)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
